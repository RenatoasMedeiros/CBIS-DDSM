# %%
# %%
# Import necessary libraries at the top
import os
import glob
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from datetime import datetime

# --- Configuration & Constants ---
MODEL_NAME = 'ResNet50'



BASE_DATASET_PATH = './k_CBIS-DDSM/'
CALC_METADATA_CSV_PATH = os.path.join(BASE_DATASET_PATH, 'calc_case(with_jpg_img).csv')
MASS_METADATA_CSV_PATH = os.path.join(BASE_DATASET_PATH, 'mass_case(with_jpg_img).csv')

IMAGE_ROOT_DIR = BASE_DATASET_PATH
ACTUAL_IMAGE_FILES_BASE_DIR = os.path.join(IMAGE_ROOT_DIR, 'jpg_img')

# Column in CSV that conceptually should point to ROIs, even if paths are flawed
CONCEPTUAL_ROI_COLUMN_NAME = 'jpg_ROI_img_path'
PATHOLOGY_COLUMN_NAME = 'pathology'
CASE_TYPE_COLUMN_NAME = 'case_type'

# Model & Training Parameters
IMG_WIDTH, IMG_HEIGHT = 224, 224
IMG_COLOR_DEPTH = 3
BATCH_SIZE = 32
EPOCHS = 500
FINE_TUNE_EPOCHS = 100
LEARNING_RATE = 1e-4
RANDOM_STATE = 42
OUTPUT_DIR = os.path.join('./', f"run_{MODEL_NAME}_{IMG_WIDTH}_{BATCH_SIZE}_D128_D64{datetime.now().strftime('%Y%m%d_%H%M%S')}")
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"All output will be saved to: {os.path.abspath(OUTPUT_DIR)}")
PATIENCE_EARLY_STOPPING = 25
PATIENCE_REDUCE_LR = 10

PATIENCE_EARLY_STOPPING_FT = 20
PATIENCE_REDUCE_LR_FT = 10
# --- End of Configuration & Constants ---

# %%
# --- [The data loading and path finding sections remain the same as your original script] ---
# ... (Assuming this part runs successfully as in your script)
print("--- Initial Path Configuration Debug ---")
print(f"Current working directory (CWD): {os.getcwd()}")
print(f"BASE_DATASET_PATH (relative from CWD as defined): {BASE_DATASET_PATH}")
print(f"CALC_METADATA_CSV_PATH (relative from CWD as defined): {CALC_METADATA_CSV_PATH}") 
print(f"MASS_METADATA_CSV_PATH (relative from CWD as defined): {MASS_METADATA_CSV_PATH}")   # ADDED
print(f"IMAGE_ROOT_DIR (relative from CWD as defined): {IMAGE_ROOT_DIR}")
print(f"ACTUAL_IMAGE_FILES_BASE_DIR (relative from CWD as defined): {ACTUAL_IMAGE_FILES_BASE_DIR}")

# Resolve to absolute paths for clarity and checking
abs_base_dataset_path = os.path.abspath(BASE_DATASET_PATH)
abs_calc_metadata_csv_path = os.path.abspath(CALC_METADATA_CSV_PATH) 
abs_mass_metadata_csv_path = os.path.abspath(MASS_METADATA_CSV_PATH)   # ADDED
abs_image_root_dir = os.path.abspath(IMAGE_ROOT_DIR)
abs_actual_image_files_base_dir = os.path.abspath(ACTUAL_IMAGE_FILES_BASE_DIR)

print(f"\nResolved BASE_DATASET_PATH to absolute: {abs_base_dataset_path}")
print(f"  -> Exists? {os.path.exists(abs_base_dataset_path)} | Is Dir? {os.path.isdir(abs_base_dataset_path)}")

print(f"Resolved CALC_METADATA_CSV_PATH to absolute: {abs_calc_metadata_csv_path}") 
print(f"  -> Exists? {os.path.exists(abs_calc_metadata_csv_path)} | Is File? {os.path.isfile(abs_calc_metadata_csv_path)}")

print(f"Resolved MASS_METADATA_CSV_PATH to absolute: {abs_mass_metadata_csv_path}")   # ADDED
print(f"  -> Exists? {os.path.exists(abs_mass_metadata_csv_path)} | Is File? {os.path.isfile(abs_mass_metadata_csv_path)}")

print(f"Resolved IMAGE_ROOT_DIR to absolute: {abs_image_root_dir}")
print(f"  -> Exists? {os.path.exists(abs_image_root_dir)} | Is Dir? {os.path.isdir(abs_image_root_dir)}")

print(f"Resolved ACTUAL_IMAGE_FILES_BASE_DIR (where series folders should be): {abs_actual_image_files_base_dir}")
print(f"  -> Exists? {os.path.exists(abs_actual_image_files_base_dir)} | Is Dir? {os.path.isdir(abs_actual_image_files_base_dir)}")

if os.path.exists(abs_actual_image_files_base_dir) and os.path.isdir(abs_actual_image_files_base_dir):
    print(f"\nSample contents of ACTUAL_IMAGE_FILES_BASE_DIR ('{abs_actual_image_files_base_dir}') (first 10 items):")
    try:
        sample_contents = os.listdir(abs_actual_image_files_base_dir)[:10]
        if not sample_contents:
            print("    -> Directory is empty or unreadable.")
        for item_idx, item in enumerate(sample_contents):
            item_abs_path = os.path.join(abs_actual_image_files_base_dir, item)
            item_type = "Dir" if os.path.isdir(item_abs_path) else "File" if os.path.isfile(item_abs_path) else "Other"
            print(f"    -> [{item_type}] {item}")
    except Exception as e:
        print(f"    -> Could not list directory contents: {e}")
else:
    print("\nCRITICAL WARNING: ACTUAL_IMAGE_FILES_BASE_DIR does not exist or is not a directory. Path searches will fail.")
print("--- End of Initial Path Configuration Debug ---\n")



print("Proceeding with CSV loading...")
loaded_dfs = []

# Load Calc cases
if os.path.exists(abs_calc_metadata_csv_path):
    try:
        calc_df = pd.read_csv(abs_calc_metadata_csv_path)
        calc_df[CASE_TYPE_COLUMN_NAME] = 'calc' # Add case type identifier
        loaded_dfs.append(calc_df)
        print(f"Successfully loaded and tagged {len(calc_df)} rows from {CALC_METADATA_CSV_PATH}")
    except Exception as e:
        print(f"An error occurred while loading the CALC CSV ({CALC_METADATA_CSV_PATH}): {e}")
else:
    print(f"WARNING: CALC CSV file not found at {abs_calc_metadata_csv_path}. Skipping.")

# Load Mass cases
if os.path.exists(abs_mass_metadata_csv_path):
    try:
        mass_df = pd.read_csv(abs_mass_metadata_csv_path)
        mass_df[CASE_TYPE_COLUMN_NAME] = 'mass' # Add case type identifier
        loaded_dfs.append(mass_df)
        print(f"Successfully loaded and tagged {len(mass_df)} rows from {MASS_METADATA_CSV_PATH}")
    except Exception as e:
        print(f"An error occurred while loading the MASS CSV ({MASS_METADATA_CSV_PATH}): {e}")
else:
    print(f"WARNING: MASS CSV file not found at {abs_mass_metadata_csv_path}. Skipping.")

if not loaded_dfs:
    print("ERROR: No CSV files were loaded. Cannot proceed.")
    raise FileNotFoundError("Neither Calc nor Mass CSV files could be loaded. Check paths and file existence.")

source_df = pd.concat(loaded_dfs, ignore_index=True)
print(f"Combined DataFrame created with {len(source_df)} total rows from {len(loaded_dfs)} CSV file(s).")
print(f"Columns available in combined DataFrame: {source_df.columns.tolist()}")


# Clean and filter initial dataframe
if CONCEPTUAL_ROI_COLUMN_NAME not in source_df.columns or PATHOLOGY_COLUMN_NAME not in source_df.columns:
    print(f"ERROR: Required columns for metadata ('{CONCEPTUAL_ROI_COLUMN_NAME}' or '{PATHOLOGY_COLUMN_NAME}') not in combined CSV.")
    print(f"Available columns are: {source_df.columns.tolist()}")
    raise KeyError("Missing essential columns in combined CSV.")

source_df.dropna(subset=[CONCEPTUAL_ROI_COLUMN_NAME, PATHOLOGY_COLUMN_NAME], inplace=True)
source_df = source_df[source_df[PATHOLOGY_COLUMN_NAME].isin(['MALIGNANT', 'BENIGN'])]
print(f"Rows after initial cleaning (dropna on conceptual ROI/pathology, pathology filter): {len(source_df)}")

if source_df.empty:
    raise ValueError("Combined DataFrame is empty after initial cleaning. Cannot proceed.")

def heuristic_find_image_path(row, actual_images_root_dir_abs):
    try:
        patient_id = row['patient_id']
        breast_side = row['left or right breast']
        image_view = row['image view']
        abnormality_id = str(row['abnormality id']) # Ensure it's a string for concatenation

        csv_conceptual_roi_path = str(row.get(CONCEPTUAL_ROI_COLUMN_NAME, "")).strip()

        case_type_folder_prefix = ""
        if csv_conceptual_roi_path.startswith("jpg_img/"):
            path_part = csv_conceptual_roi_path.split('/')[1] # e.g., "Calc_Training_P_00005_..." or "Mass_Test_P_00001_..."
            # Extract the part before patient_id
            # The heuristic already includes Mass_Training and Mass_Test
            if path_part.startswith("Calc_Training_"): case_type_folder_prefix = "Calc_Training"
            elif path_part.startswith("Calc_Test_"): case_type_folder_prefix = "Calc_Test"
            elif path_part.startswith("Mass_Training_"): case_type_folder_prefix = "Mass_Training"
            elif path_part.startswith("Mass_Test_"): case_type_folder_prefix = "Mass_Test"

        if not case_type_folder_prefix:
            # print(f"DEBUG (heuristic): Could not determine case_type_folder_prefix for {patient_id} from '{csv_conceptual_roi_path}'")
            return None

        # Form search pattern for directories: e.g., /path/to/jpg_img/Calc_Training_P_00005_RIGHT_CC_1-*
        dir_search_prefix = f"{case_type_folder_prefix}_{patient_id}_{breast_side}_{image_view}_{abnormality_id}"
        full_dir_search_pattern = os.path.join(actual_images_root_dir_abs, f"{dir_search_prefix}-*")

        potential_series_dirs = glob.glob(full_dir_search_pattern)

        if not potential_series_dirs:
            # print(f"DEBUG (heuristic): No series directory found for {patient_id} with pattern '{full_dir_search_pattern}'")
            return None

        roi_filename_patterns = [
            "ROI-mask-images-img_0-*.jpg", "ROI-mask-images-img_1-*.jpg", "ROI-mask-images-img_*-*.jpg"
        ]

        for series_dir_on_disk in sorted(potential_series_dirs): # Sort to get a consistent choice if multiple match
            if os.path.isdir(series_dir_on_disk):
                for pattern in roi_filename_patterns:
                    image_search_glob = os.path.join(series_dir_on_disk, pattern)
                    found_roi_files = glob.glob(image_search_glob)
                    if found_roi_files:
                        found_roi_files.sort() # Sort to get a consistent choice
                        return found_roi_files[0] # Return the first valid ROI found
        return None
    except Exception as e:
        # print(f"DEBUG (heuristic): Error for row {row.get('patient_id', 'Unknown')} ({row.get(CASE_TYPE_COLUMN_NAME, 'N/A')} case): {e}")
        return None

print("Attempting HEURISTIC search for valid ROI paths for each CSV entry...")
source_df['full_image_path'] = source_df.apply(
    lambda r: heuristic_find_image_path(r, abs_actual_image_files_base_dir), axis=1
)

# All columns from source_df (including 'case_type' and any other original metadata)
# will be carried into metadata_df for rows where an image path was found.
metadata_df = source_df.dropna(subset=['full_image_path']).copy()
found_image_count = len(metadata_df)
print(f"Found {found_image_count} actual image files (ROIs if available) after HEURISTIC search from combined data.")
print(f"Breakdown by case type (if available in metadata_df): \n{metadata_df[CASE_TYPE_COLUMN_NAME].value_counts()}")


if found_image_count == 0:
    print("CRITICAL ERROR: Still no valid image files found even after heuristic search from combined data.")
    raise FileNotFoundError("No usable image files found even with heuristic search from combined data.")

metadata_df.rename(columns={'full_image_path': 'full_roi_path'}, inplace=True)

label_encoder = LabelEncoder()
# Ensure 'pathology_encoded' is created correctly on the copied DataFrame slice
metadata_df.loc[:, 'pathology_encoded'] = label_encoder.fit_transform(metadata_df[PATHOLOGY_COLUMN_NAME])
target_names = list(label_encoder.classes_)

# X will contain the image paths, y will contain the encoded labels.
# All other metadata columns (like 'patient_id', 'case_type', etc.) remain in metadata_df
# and can be used for deeper analysis or if a multi-input model is developed later.
X = metadata_df['full_roi_path']
y = metadata_df['pathology_encoded']
print(f"Number of samples going into train_test_split: {len(X)}")

if len(X) == 0:
     raise ValueError("Dataset is empty, cannot split.")

# Stratify by y to ensure balanced splits, especially important if classes are imbalanced
# or if combining datasets leads to different proportions.
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.15, random_state=RANDOM_STATE, stratify=y
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.15, random_state=RANDOM_STATE, stratify=y_train_val # Stratify this split too
)

print(f"Training samples: {len(X_train)}")
print(f"Validation samples: {len(X_val)}")
print(f"Test samples: {len(X_test)}")

# Print class distribution in each set to verify stratification
print(f"Train labels distribution: {np.bincount(y_train)}")
print(f"Validation labels distribution: {np.bincount(y_val)}")
print(f"Test labels distribution: {np.bincount(y_test)}")


def load_image(image_path_tensor, label_tensor):
    image_path_str = image_path_tensor.numpy().decode('utf-8')
    try:
        img = cv2.imread(image_path_str)
        if img is None: # Check if image loading failed
            dummy_img = np.zeros((IMG_HEIGHT, IMG_WIDTH, IMG_COLOR_DEPTH), dtype=np.uint8)
            error_label = np.int32(-1) # Special label to indicate a problem
            return dummy_img, error_label

        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))
        return img, label_tensor.numpy().astype(np.int32)
    except Exception as e:
        dummy_img = np.zeros((IMG_HEIGHT, IMG_WIDTH, IMG_COLOR_DEPTH), dtype=np.uint8)
        error_label = np.int32(-1)
        return dummy_img, error_label

# Data Augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomBrightness(factor=0.1),
    tf.keras.layers.RandomContrast(factor=0.1)
])

def create_tf_dataset(image_paths, labels, batch_size, augment=False):
    image_paths_list = list(image_paths)
    labels_list = list(labels)

    dataset = tf.data.Dataset.from_tensor_slices((image_paths_list, labels_list))

    # Step 1: Load images
    dataset = dataset.map(lambda x, y: tf.py_function(
        load_image,
        [x, y],
        [tf.uint8, tf.int32]),
        num_parallel_calls=tf.data.AUTOTUNE)

    # Step 2: Filter failed loads
    dataset = dataset.filter(lambda img, label: label != -1)

    # Step 3: Set tensor shapes
    def set_shape(img, label):
        img.set_shape((IMG_WIDTH, IMG_HEIGHT, IMG_COLOR_DEPTH))
        label.set_shape(())
        return img, label
    dataset = dataset.map(set_shape, num_parallel_calls=tf.data.AUTOTUNE)

    # Cast to float32
    dataset = dataset.map(lambda img, label: (tf.cast(img, tf.float32), label),
                          num_parallel_calls=tf.data.AUTOTUNE)
    
    # Batch before augmentation
    dataset = dataset.batch(batch_size)

    # Step 4: Apply augmentation with keyword argument
    if augment:
        dataset = dataset.map(lambda x, y: (data_augmentation(x, training=True), y),  # Use keyword
                              num_parallel_calls=tf.data.AUTOTUNE)

    # Step 5: Apply preprocessing
    dataset = dataset.map(lambda x, y: (tf.keras.applications.efficientnet.preprocess_input(x), y),
                          num_parallel_calls=tf.data.AUTOTUNE)

    # Step 6: Prefetch
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset

def visualize_augmentations(sample_image_paths, augmentation_layer, output_dir):
    print("Generating and saving data augmentation visualization...")
    num_examples = len(sample_image_paths)
    num_augmentations = 4 # How many augmented versions to show for each original
    
    plt.figure(figsize=(5 * num_augmentations, 5 * num_examples))
    
    for i, image_path in enumerate(sample_image_paths):
        # Load the original image using a simplified version of the preprocessing
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))
        
        # Display the original image
        ax = plt.subplot(num_examples, num_augmentations + 1, i * (num_augmentations + 1) + 1)
        plt.imshow(img)
        plt.title(f"Original {i+1}")
        plt.axis("off")
        
        # Add batch dimension and apply augmentations
        img_tensor = tf.expand_dims(tf.convert_to_tensor(img), 0)
        for j in range(num_augmentations):
            augmented_image = augmentation_layer(img_tensor, training=True)
            ax = plt.subplot(num_examples, num_augmentations + 1, i * (num_augmentations + 1) + j + 2)
            plt.imshow(tf.squeeze(augmented_image, axis=0).numpy().astype("uint8"))
            plt.title(f"Augmented {j+1}")
            plt.axis("off")
            
    plt.tight_layout()
    # Save the figure to the specified output directory
    save_path = os.path.join(output_dir, "data_augmentation_examples.png")
    plt.savefig(save_path)
    print(f"Augmentation visualization saved to {save_path}")
    plt.show()

# --- Call the new visualization function ---
# Take a few sample images from the training set to show
num_viz_samples = 3
if len(X_train) >= num_viz_samples:
    visualize_augmentations(
        sample_image_paths=X_train.iloc[:num_viz_samples],
        augmentation_layer=data_augmentation,
        output_dir=OUTPUT_DIR
    )

print("Recreating TensorFlow datasets with updated image loading logic...")
train_dataset = create_tf_dataset(X_train, y_train, BATCH_SIZE, augment=True)
val_dataset = create_tf_dataset(X_val, y_val, BATCH_SIZE, augment=False)
test_dataset = create_tf_dataset(X_test, y_test, BATCH_SIZE, augment=False)

print("Verifying dataset integrity (this might take a moment)...")
train_batches = 0
train_samples_effective = 0
for images, labels in train_dataset:
    train_batches += 1
    train_samples_effective += labels.shape[0]
print(f"Number of batches in train_dataset: {train_batches}")
print(f"Effective number of samples in train_dataset after filtering: {train_samples_effective}")

if train_batches > 0:
    for images, labels in train_dataset.take(1):
        print("Sample batch shape from train_dataset:", images.shape, labels.shape)
else:
    print("Warning: train_dataset is empty after filtering. Check for widespread image loading issues.")

val_batches = 0
val_samples_effective = 0
for images, labels in val_dataset:
    val_batches +=1
    val_samples_effective += labels.shape[0]
print(f"Number of batches in val_dataset: {val_batches}")
print(f"Effective number of samples in val_dataset after filtering: {val_samples_effective}")


test_batches = 0
test_samples_effective = 0
for images, labels in test_dataset:
    test_batches += 1
    test_samples_effective += labels.shape[0]
print(f"Number of batches in test_dataset: {test_batches}")
print(f"Effective number of samples in test_dataset after filtering: {test_samples_effective}")


# Check if any dataset is empty, which could cause issues during training/evaluation
if train_samples_effective == 0 or val_samples_effective == 0:
    print("CRITICAL WARNING: Training or Validation dataset is empty after processing. Model training cannot proceed effectively.")
    # Depending on the severity, you might want to raise an error here
    # raise ValueError("Training or Validation dataset is empty.")


# %%
# --- 2. Model Architecture ---
print("\nPhase 2: Building the Model")
base_model = ResNet50(include_top=False, weights='imagenet',
                            input_shape=(IMG_WIDTH, IMG_HEIGHT, IMG_COLOR_DEPTH))
base_model.trainable = False # Start with base model frozen

inputs = Input(shape=(IMG_WIDTH, IMG_HEIGHT, IMG_COLOR_DEPTH))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D(name="avg_pool")(x)
x = Dropout(0.3, name="top_dropout_1")(x)
x = Dense(128, activation='relu', name="dense_128")(x)
x = Dropout(0.3, name="top_dropout_2")(x)
x = Dense(64, activation='relu', name="dense_64")(x)
x = Dropout(0.2, name="top_dropout_3")(x)
outputs = Dense(1, activation='sigmoid', name="predictions")(x)
model = Model(inputs, outputs)

# %%
# --- 3. Model Compilation ---
print("\nPhase 3: Compiling the Model")
optimizer = Adam(learning_rate=LEARNING_RATE)

# MODIFIED: Adjust loss based on number of classes
if len(target_names) <= 2: # Binary classification (or single class if an error, but usually benign/malignant)
    loss = tf.keras.losses.BinaryCrossentropy()
    # For binary, ensure 'accuracy' is suitable. AUC, Precision, Recall are fine.
    metrics = ['accuracy', tf.keras.metrics.AUC(name='auc'),
               tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
else: # Multiclass classification
    loss = tf.keras.losses.SparseCategoricalCrossentropy() # Assuming y_train, etc., are integer labels
    metrics = ['accuracy', tf.keras.metrics.AUC(name='auc')] # AUC might need multi_label=True or specific setup for multiclass
    # For multiclass, typical metrics are accuracy, sparse_categorical_accuracy.
    # Precision and Recall can be more complex (e.g., weighted, macro).
    # For simplicity, starting with accuracy and AUC.

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
model.summary()

print("Available metrics names:", model.metrics_names)

# %%
print("\nPhase 4: Training the Model (Head Only)")
# Ensure datasets are not empty before starting training
if train_samples_effective == 0 or val_samples_effective == 0:
    print("ERROR: Cannot start head training because train or validation dataset is empty.")
else:

    checkpoint_filepath_head = os.path.join(OUTPUT_DIR, 'best_model_head_only.keras')
    callbacks_head = [
        ModelCheckpoint(filepath=checkpoint_filepath_head, save_weights_only=False, monitor='val_auc', mode='max', save_best_only=True),
        EarlyStopping(monitor='val_auc', patience=PATIENCE_EARLY_STOPPING, mode='max', restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=PATIENCE_REDUCE_LR, min_lr=1e-7, mode='min')
    ]
    history_head = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks_head
    )
    print("Loading best weights from head training...")
    if os.path.exists(checkpoint_filepath_head):
        model.load_weights(checkpoint_filepath_head)
    else:
        print(f"Warning: Checkpoint file {checkpoint_filepath_head} not found. Using last model weights.")


# --- 4b. Fine-tuning Phase ---
print("\nPhase 4b: Fine-tuning (Unfreezing some base model layers)")
base_model.trainable = True

# Unfreeze layers from a certain block onwards in EfficientNetB0
# EfficientNetB0 has blocks named 'block2a_expand_conv', 'block3a_expand_conv', ..., 'block7a_expand_conv'
# We can choose to unfreeze from 'block6a' or 'block5a' onwards
# For this example, let's unfreeze from 'block5a' onwards.
# You might need to inspect base_model.summary() to choose the right layers.

# Fine-tuning strategy: Unfreeze more layers
# Set base_model.trainable = True first
# Then, selectively re-freeze earlier layers if desired
# For EfficientNet, it's common to unfreeze the top blocks.

fine_tune_at_layer_name = 'block6a_expand_conv' # Here we are just unfrezzing one
set_trainable = False
for layer in base_model.layers:
    if layer.name == fine_tune_at_layer_name:
        set_trainable = True
    if set_trainable:
        if not isinstance(layer, tf.keras.layers.BatchNormalization): # Keep BN frozen
            layer.trainable = True
        else:
            layer.trainable = False # Explicitly keep BN frozen
    else:
        layer.trainable = False


optimizer_fine_tune = Adam(learning_rate=LEARNING_RATE / 10) # Use a smaller LR
model.compile(optimizer=optimizer_fine_tune, loss=loss, metrics=metrics) # Re-compile
model.summary() # Show summary with new trainable params
if train_samples_effective == 0 or val_samples_effective == 0:
     print("ERROR: Cannot start fine-tuning because train or validation dataset is empty.")
else:

    checkpoint_filepath_finetune = os.path.join(OUTPUT_DIR, 'best_model_finetuned.keras')
    callbacks_finetune = [
        ModelCheckpoint(filepath=checkpoint_filepath_finetune, save_weights_only=False, monitor='val_accuracy', mode='max', save_best_only=True),
        EarlyStopping(monitor='val_auc', patience=PATIENCE_EARLY_STOPPING_FT, mode='max', restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=PATIENCE_REDUCE_LR_FT, min_lr=1e-8, mode='min')
    ]

    # Determine initial epoch for fine-tuning
    initial_fine_tune_epoch = 0
    if 'history_head' in locals() and hasattr(history_head, 'epoch') and history_head.epoch:
        initial_fine_tune_epoch = history_head.epoch[-1] + 1
    else: # If head training was skipped or history is unavailable
        initial_fine_tune_epoch = 0 # Or EPOCHS if you want to assume head training ran for all its epochs
        EPOCHS = 0 # Ensure we don't re-run head training if it was skipped

    history_fine_tune = model.fit(
        train_dataset,
        epochs=EPOCHS + FINE_TUNE_EPOCHS, # Total epochs
        initial_epoch=initial_fine_tune_epoch, # Continue from where head training left off
        validation_data=val_dataset,
        callbacks=callbacks_finetune
    )
    print("Loading best weights from fine-tuning...")
    if os.path.exists(checkpoint_filepath_finetune):
        model.load_weights(checkpoint_filepath_finetune)
    else:
        print(f"Warning: Checkpoint file {checkpoint_filepath_finetune} not found. Using last model weights from fine-tuning.")



# %%
# --- 5. Model Evaluation ---
print("\nPhase 5: Evaluating the Model on Test Set")

if test_samples_effective == 0:
    print("ERROR: Test dataset is empty. Cannot evaluate model.")
    test_accuracy = 0
    test_auc = 0
else:
    results = model.evaluate(test_dataset, verbose=1)
    if len(results) >= 5:  # Ensure there are enough metrics
        final_loss = results[0]
        final_acc = results[1]  # Accuracy
        final_auc = results[2]  # AUC
        final_precision = results[3]  # Precision
        final_recall = results[4]  # Recall
        print(f"Final Loss: {final_loss}")
        print(f"Final Accuracy: {final_acc}")
        print(f"Final AUC: {final_auc}")
        print(f"Final Precision: {final_precision}")
        print(f"Final Recall: {final_recall}")
        history_plot_filename = f"training_history_Acc{final_acc:.3f}_AUC{final_auc:.3f}.png"
    else:
        print("Error: Not enough metrics returned from model.evaluate")

    print("Number of results:", len(results))
    print("Results:", results)
    y_pred_proba = model.predict(test_dataset)

    # Extract true labels correctly, regardless of whether test_dataset was batched
    y_true_test = []
    for _, labels_batch in test_dataset.unbatch().batch(BATCH_SIZE): # Re-batch after unbatching to iterate easily
        y_true_test.extend(labels_batch.numpy())
    y_true_test = np.array(y_true_test)

    if len(target_names) <= 2: # Binary classification
        y_pred_classes = (y_pred_proba > 0.5).astype(int).flatten()
    else: # Multiclass classification
        y_pred_classes = np.argmax(y_pred_proba, axis=1)


    if len(y_true_test) == 0:
        print("Warning: No true labels extracted from the test set. Cannot generate classification report or confusion matrix.")
    elif len(y_true_test) != len(y_pred_classes):
         print(f"Warning: Mismatch in number of true labels ({len(y_true_test)}) and predicted classes ({len(y_pred_classes)}). Skipping report/matrix.")
    else:
        print("\nClassification Report (Test Set):")
        print(classification_report(y_true_test, y_pred_classes, target_names=target_names, labels=range(len(target_names))))


        cm = confusion_matrix(y_true_test, y_pred_classes, labels=range(len(target_names)))
        print("\nConfusion Matrix (Test Set):")
        print(cm)

        plt.figure(figsize=(8,8)) # Made figure a bit bigger
        ax = plt.gca()
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
        disp.plot(cmap=plt.cm.Blues, ax=ax, values_format='d')
        plt.title('Confusion Matrix (Test Set)', fontsize=18)
        
    
        cm_save_path = os.path.join(OUTPUT_DIR, "confusion_matrix.png")
        plt.savefig(cm_save_path)
        print(f"Confusion matrix saved to {cm_save_path}")
        plt.show()


# Plot Training History (combined)
# Ensure histories exist before trying to plot
acc, val_acc, loss_hist, val_loss_hist, auc, val_auc = [], [], [], [], [], []
epochs_range_head_len = 0

if 'history_head' in locals() and hasattr(history_head, 'history'):
    acc.extend(history_head.history.get('accuracy', []))
    val_acc.extend(history_head.history.get('val_accuracy', []))
    loss_hist.extend(history_head.history.get('loss', []))
    val_loss_hist.extend(history_head.history.get('val_loss', []))
    auc.extend(history_head.history.get('auc', []))
    val_auc.extend(history_head.history.get('val_auc', []))
    epochs_range_head_len = len(history_head.history.get('accuracy', []))

if 'history_fine_tune' in locals() and hasattr(history_fine_tune, 'history'):
    acc.extend(history_fine_tune.history.get('accuracy', []))
    val_acc.extend(history_fine_tune.history.get('val_accuracy', []))
    loss_hist.extend(history_fine_tune.history.get('loss', []))
    val_loss_hist.extend(history_fine_tune.history.get('val_loss', []))
    auc.extend(history_fine_tune.history.get('auc', []))
    val_auc.extend(history_fine_tune.history.get('val_auc', []))

epochs_range_total = range(len(acc))

if epochs_range_total: # Only plot if there's history
    plt.figure(figsize=(20, 8)) # Made figure wider
    
    # Plot Accuracy
    plt.subplot(1, 3, 1)
    plt.plot(epochs_range_total, acc, label='Training Accuracy')
    plt.plot(epochs_range_total, val_acc, label='Validation Accuracy')
    if epochs_range_head_len > 0 and epochs_range_head_len < len(epochs_range_total):
        plt.axvline(x=epochs_range_head_len -1 , color='gray', linestyle='--', label='Start Fine-tuning')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range_total, loss_hist, label='Training Loss')
    plt.plot(epochs_range_total, val_loss_hist, label='Validation Loss')
    if epochs_range_head_len > 0 and epochs_range_head_len < len(epochs_range_total):
        plt.axvline(x=epochs_range_head_len -1, color='gray', linestyle='--', label='Start Fine-tuning')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    # Plot AUC
    plt.subplot(1, 3, 3)
    plt.plot(epochs_range_total, auc, label='Training AUC')
    plt.plot(epochs_range_total, val_auc, label='Validation AUC')
    if epochs_range_head_len > 0 and epochs_range_head_len < len(epochs_range_total):
        plt.axvline(x=epochs_range_head_len-1, color='gray', linestyle='--', label='Start Fine-tuning')
    plt.legend(loc='lower right')
    plt.title('Training and Validation AUC')
    plt.xlabel('Epochs')
    plt.ylabel('AUC')

    plt.tight_layout()
    

    print("Available metrics names:", model.metrics_names)
    # Use the metrics already extracted in the evaluation section
    final_acc = results[1]  # Accuracy
    final_auc = results[2]  # AUC
    history_plot_filename = f"training_history_Acc{final_acc:.3f}_AUC{final_auc:.3f}.png"
    history_save_path = os.path.join(OUTPUT_DIR, history_plot_filename)
    plt.savefig(history_save_path)
    print(f"Training history plot saved to {history_save_path}")
    
    plt.show()
else:
    print("No training history found to plot.")

print("\n--- End of Training ---")
# Out:
# 2025-06-11 23:03:39.477557: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749679419.489504   26317 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749679419.493069   26317 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1749679419.502882   26317 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749679419.502898   26317 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749679419.502900   26317 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749679419.502901   26317 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-11 23:03:39.506290: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# All output will be saved to: /home/luui/Documents/Uni/SystemsSensitiveToContext/PL/CBIS-DDSM/run_ResNet50_20250611_230341
# --- Initial Path Configuration Debug ---
# Current working directory (CWD): /home/luui/Documents/Uni/SystemsSensitiveToContext/PL/CBIS-DDSM
# BASE_DATASET_PATH (relative from CWD as defined): ./k_CBIS-DDSM/
# CALC_METADATA_CSV_PATH (relative from CWD as defined): ./k_CBIS-DDSM/calc_case(with_jpg_img).csv
# MASS_METADATA_CSV_PATH (relative from CWD as defined): ./k_CBIS-DDSM/mass_case(with_jpg_img).csv
# IMAGE_ROOT_DIR (relative from CWD as defined): ./k_CBIS-DDSM/
# ACTUAL_IMAGE_FILES_BASE_DIR (relative from CWD as defined): ./k_CBIS-DDSM/jpg_img
#
# Resolved BASE_DATASET_PATH to absolute: /home/luui/Documents/Uni/SystemsSensitiveToContext/PL/CBIS-DDSM/k_CBIS-DDSM
#   -> Exists? True | Is Dir? True
# Resolved CALC_METADATA_CSV_PATH to absolute: /home/luui/Documents/Uni/SystemsSensitiveToContext/PL/CBIS-DDSM/k_CBIS-DDSM/calc_case(with_jpg_img).csv
#   -> Exists? True | Is File? True
# Resolved MASS_METADATA_CSV_PATH to absolute: /home/luui/Documents/Uni/SystemsSensitiveToContext/PL/CBIS-DDSM/k_CBIS-DDSM/mass_case(with_jpg_img).csv
#   -> Exists? True | Is File? True
# Resolved IMAGE_ROOT_DIR to absolute: /home/luui/Documents/Uni/SystemsSensitiveToContext/PL/CBIS-DDSM/k_CBIS-DDSM
#   -> Exists? True | Is Dir? True
# Resolved ACTUAL_IMAGE_FILES_BASE_DIR (where series folders should be): /home/luui/Documents/Uni/SystemsSensitiveToContext/PL/CBIS-DDSM/k_CBIS-DDSM/jpg_img
#   -> Exists? True | Is Dir? True
#
# Sample contents of ACTUAL_IMAGE_FILES_BASE_DIR ('/home/luui/Documents/Uni/SystemsSensitiveToContext/PL/CBIS-DDSM/k_CBIS-DDSM/jpg_img') (first 10 items):
#     -> [Dir] Calc_Training_P_00705_LEFT_MLO-1.3.6.1.4.1.9590.100.1.2.354279926413518261338892911371986919720-1.3.6.1.4.1.9590.100.1.2.152683524611189484109254424593944167659
#     -> [Dir] Mass_Training_P_01714_RIGHT_MLO_1-1.3.6.1.4.1.9590.100.1.2.375882620113203187615094432623959494608-1.3.6.1.4.1.9590.100.1.2.577657812640027026952728342913961044
#     -> [Dir] Calc_Training_P_00291_LEFT_CC_1-1.3.6.1.4.1.9590.100.1.2.334364876511040573436436345854266353445-1.3.6.1.4.1.9590.100.1.2.411253025311100641804555022153278303233
#     -> [Dir] Mass_Training_P_00765_RIGHT_MLO_1-1.3.6.1.4.1.9590.100.1.2.62502724512019571739059690801715953121-1.3.6.1.4.1.9590.100.1.2.320866693113864447514884110163742534443
#     -> [Dir] Calc_Test_P_00141_LEFT_CC_1-1.3.6.1.4.1.9590.100.1.2.256141081410886290729430181220263631788-1.3.6.1.4.1.9590.100.1.2.405140190212844073842668438022072159427
#     -> [Dir] Mass_Test_P_00194_RIGHT_CC_1-1.3.6.1.4.1.9590.100.1.2.304870700011148451342362292482610814034-1.3.6.1.4.1.9590.100.1.2.205826898113630199908418083061888658721
#     -> [Dir] Calc_Training_P_00364_RIGHT_MLO_1-1.3.6.1.4.1.9590.100.1.2.178845899411776841012412376523922011081-1.3.6.1.4.1.9590.100.1.2.426766378412007204136492384452762527280
#     -> [Dir] Calc_Training_P_01823_LEFT_MLO_1-1.3.6.1.4.1.9590.100.1.2.108831426910832432405107985244184244356-1.3.6.1.4.1.9590.100.1.2.49930338811933162134369020202402665286
#     -> [Dir] Calc_Training_P_00339_LEFT_MLO_1-1.3.6.1.4.1.9590.100.1.2.194945988912578043638609982753903428414-1.3.6.1.4.1.9590.100.1.2.143175863512104959640940942652544463784
#     -> [Dir] Mass_Training_P_01035_RIGHT_MLO_1-1.3.6.1.4.1.9590.100.1.2.185167727111719003342021487562605321018-1.3.6.1.4.1.9590.100.1.2.189998935511372521626412991152082898357
# --- End of Initial Path Configuration Debug ---
#
# Proceeding with CSV loading...
# Successfully loaded and tagged 1872 rows from ./k_CBIS-DDSM/calc_case(with_jpg_img).csv
# Successfully loaded and tagged 1696 rows from ./k_CBIS-DDSM/mass_case(with_jpg_img).csv
# Combined DataFrame created with 3568 total rows from 2 CSV file(s).
# Columns available in combined DataFrame: ['patient_id', 'breast density', 'left or right breast', 'image view', 'abnormality id', 'abnormality type', 'calc type', 'calc distribution', 'assessment', 'pathology', 'subtlety', 'jpg_fullMammo_img_path', 'jpg_crop_img_path', 'jpg_ROI_img_path', 'case_type', 'breast_density', 'mass shape', 'mass margins']
# Rows after initial cleaning (dropna on conceptual ROI/pathology, pathology filter): 2886
# Attempting HEURISTIC search for valid ROI paths for each CSV entry...
# Found 2883 actual image files (ROIs if available) after HEURISTIC search from combined data.
# Breakdown by case type (if available in metadata_df):
# case_type
# mass    1553
# calc    1330
# Name: count, dtype: int64
# Number of samples going into train_test_split: 2883
# Training samples: 2082
# Validation samples: 368
# Test samples: 433
# Train labels distribution: [1032 1050]
# Validation labels distribution: [182 186]
# Test labels distribution: [215 218]
# Generating and saving data augmentation visualization...
# I0000 00:00:1749679443.179841   26317 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 753 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:10:00.0, compute capability: 7.5
# Augmentation visualization saved to ./run_ResNet50_20250611_230341/data_augmentation_examples.png
# Recreating TensorFlow datasets with updated image loading logic...
# Verifying dataset integrity (this might take a moment)...
# 2025-06-11 23:04:17.009394: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Number of batches in train_dataset: 66
# Effective number of samples in train_dataset after filtering: 2082
# Sample batch shape from train_dataset: (32, 224, 224, 3) (32,)
# 2025-06-11 23:04:17.750124: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Number of batches in val_dataset: 12
# Effective number of samples in val_dataset after filtering: 368
# 2025-06-11 23:04:21.283241: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Number of batches in test_dataset: 14
# Effective number of samples in test_dataset after filtering: 433
#
# Phase 2: Building the Model
#
# Phase 3: Compiling the Model
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ avg_pool                        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ top_dropout_1 (Dropout)         │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_128 (Dense)               │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ top_dropout_2 (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ top_dropout_3 (Dropout)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,858,305 (91.01 MB)
#  Trainable params: 270,593 (1.03 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Available metrics names: ['loss', 'compile_metrics']
#
# Phase 4: Training the Model (Head Only)
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749679466.765410   42736 service.cc:152] XLA service 0x60ca26cc98e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749679466.765459   42736 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2025-06-11 23:04:27.266171: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1749679469.375890   42736 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-06-11 23:04:30.340772: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 610.06MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-11 23:04:30.490672: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.162 = (f32[32,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,56,56]{3,2,1,0} %bitcast.13241, f32[64,64,3,3]{3,2,1,0} %bitcast.13248, f32[64]{0} %bitcast.13250), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv2_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:04:30.931209: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 808.06MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-11 23:04:31.217172: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.172 = (f32[32,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,28,28]{3,2,1,0} %bitcast.13646, f32[128,128,3,3]{3,2,1,0} %bitcast.13653, f32[128]{0} %bitcast.13655), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv3_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:04:31.595763: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 594.25MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-11 23:04:31.726747: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 696.25MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-11 23:04:32.084024: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.185 = (f32[32,256,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,14,14]{3,2,1,0} %bitcast.14174, f32[256,256,3,3]{3,2,1,0} %bitcast.14181, f32[256]{0} %bitcast.14183), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv4_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:04:32.224678: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 356.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-11 23:04:32.391049: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 611.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-11 23:04:32.486393: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 665.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-11 23:04:32.912604: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.204 = (f32[32,512,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,7,7]{3,2,1,0} %bitcast.14948, f32[512,512,3,3]{3,2,1,0} %bitcast.14955, f32[512]{0} %bitcast.14957), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv5_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:04:33.113845: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 637.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-11 23:04:33.113879: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-06-11 23:04:33.222199: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#       1/Unknown 13s 13s/step - accuracy: 0.5938 - auc: 0.5911 - loss: 0.6926 - precision: 0.6250 - recall: 0.7895
# I0000 00:00:1749679475.074479   42736 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#      65/Unknown 25s 191ms/step - accuracy: 0.5079 - auc: 0.5281 - loss: 0.7596 - precision: 0.5095 - recall: 0.5347
# 2025-06-11 23:04:49.149266: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.172 = (f32[2,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,128,28,28]{3,2,1,0} %bitcast.13648, f32[128,128,3,3]{3,2,1,0} %bitcast.13655, f32[128]{0} %bitcast.13657), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv3_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:04:49.462114: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.185 = (f32[2,256,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,256,14,14]{3,2,1,0} %bitcast.14176, f32[256,256,3,3]{3,2,1,0} %bitcast.14183, f32[256]{0} %bitcast.14185), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv4_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:04:49.766304: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.204 = (f32[2,512,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,512,7,7]{3,2,1,0} %bitcast.14950, f32[512,512,3,3]{3,2,1,0} %bitcast.14957, f32[512]{0} %bitcast.14959), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv5_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
#      66/Unknown 29s 252ms/step - accuracy: 0.5078 - auc: 0.5279 - loss: 0.7596 - precision: 0.5094 - recall: 0.5346
# /home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 2025-06-11 23:04:57.977449: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.162 = (f32[16,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,56,56]{3,2,1,0} %bitcast.5280, f32[64,64,3,3]{3,2,1,0} %bitcast.5287, f32[64]{0} %bitcast.5289), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv2_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:04:58.512280: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.172 = (f32[16,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,28,28]{3,2,1,0} %bitcast.5685, f32[128,128,3,3]{3,2,1,0} %bitcast.5692, f32[128]{0} %bitcast.5694), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv3_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:04:59.140143: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.185 = (f32[16,256,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,14,14]{3,2,1,0} %bitcast.6213, f32[256,256,3,3]{3,2,1,0} %bitcast.6220, f32[256]{0} %bitcast.6222), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv4_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:04:59.830973: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.204 = (f32[16,512,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,512,7,7]{3,2,1,0} %bitcast.6987, f32[512,512,3,3]{3,2,1,0} %bitcast.6994, f32[512]{0} %bitcast.6996), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv5_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:05:01.184977: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 40s 410ms/step - accuracy: 0.5077 - auc: 0.5277 - loss: 0.7596 - precision: 0.5093 - recall: 0.5345 - val_accuracy: 0.5489 - val_auc: 0.5671 - val_loss: 0.6879 - val_precision: 0.5962 - val_recall: 0.3333 - learning_rate: 1.0000e-04
# Epoch 2/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 19s 275ms/step - accuracy: 0.5420 - auc: 0.5495 - loss: 0.7229 - precision: 0.5456 - recall: 0.5422 - val_accuracy: 0.5598 - val_auc: 0.5928 - val_loss: 0.6810 - val_precision: 0.5984 - val_recall: 0.3925 - learning_rate: 1.0000e-04
# Epoch 3/500
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.5524 - auc: 0.5659 - loss: 0.7044 - precision: 0.5536 - recall: 0.5588
# 2025-06-11 23:05:38.126231: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 272ms/step - accuracy: 0.5520 - auc: 0.5654 - loss: 0.7047 - precision: 0.5533 - recall: 0.5593 - val_accuracy: 0.5815 - val_auc: 0.6134 - val_loss: 0.6768 - val_precision: 0.6013 - val_recall: 0.5108 - learning_rate: 1.0000e-04
# Epoch 4/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 266ms/step - accuracy: 0.5389 - auc: 0.5676 - loss: 0.7018 - precision: 0.5404 - recall: 0.5518 - val_accuracy: 0.5625 - val_auc: 0.6057 - val_loss: 0.6782 - val_precision: 0.5758 - val_recall: 0.5108 - learning_rate: 1.0000e-04
# Epoch 5/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 19s 275ms/step - accuracy: 0.5665 - auc: 0.5860 - loss: 0.6931 - precision: 0.5669 - recall: 0.5822 - val_accuracy: 0.5761 - val_auc: 0.6154 - val_loss: 0.6734 - val_precision: 0.5824 - val_recall: 0.5699 - learning_rate: 1.0000e-04
# Epoch 6/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 19s 275ms/step - accuracy: 0.5669 - auc: 0.5927 - loss: 0.6846 - precision: 0.5652 - recall: 0.6030 - val_accuracy: 0.5870 - val_auc: 0.6304 - val_loss: 0.6711 - val_precision: 0.6308 - val_recall: 0.4409 - learning_rate: 1.0000e-04
# Epoch 7/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 266ms/step - accuracy: 0.5749 - auc: 0.6026 - loss: 0.6821 - precision: 0.5784 - recall: 0.5759 - val_accuracy: 0.6005 - val_auc: 0.6280 - val_loss: 0.6711 - val_precision: 0.6466 - val_recall: 0.4624 - learning_rate: 1.0000e-04
# Epoch 8/500
# 2025-06-11 23:06:51.847269: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 19s 279ms/step - accuracy: 0.5707 - auc: 0.5956 - loss: 0.6837 - precision: 0.5750 - recall: 0.5659 - val_accuracy: 0.5978 - val_auc: 0.6353 - val_loss: 0.6690 - val_precision: 0.6397 - val_recall: 0.4677 - learning_rate: 1.0000e-04
# Epoch 9/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 266ms/step - accuracy: 0.5913 - auc: 0.6218 - loss: 0.6702 - precision: 0.5925 - recall: 0.5956 - val_accuracy: 0.5625 - val_auc: 0.6262 - val_loss: 0.6710 - val_precision: 0.5806 - val_recall: 0.4839 - learning_rate: 1.0000e-04
# Epoch 10/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 268ms/step - accuracy: 0.5620 - auc: 0.5878 - loss: 0.6861 - precision: 0.5633 - recall: 0.5840 - val_accuracy: 0.5625 - val_auc: 0.6202 - val_loss: 0.6712 - val_precision: 0.5940 - val_recall: 0.4247 - learning_rate: 1.0000e-04
# Epoch 11/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 256ms/step - accuracy: 0.5779 - auc: 0.6321 - loss: 0.6659 - precision: 0.5826 - recall: 0.5717 - val_accuracy: 0.5951 - val_auc: 0.6194 - val_loss: 0.6711 - val_precision: 0.6057 - val_recall: 0.5699 - learning_rate: 1.0000e-04
# Epoch 12/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.5698 - auc: 0.5887 - loss: 0.6855 - precision: 0.5692 - recall: 0.5917 - val_accuracy: 0.5625 - val_auc: 0.6184 - val_loss: 0.6694 - val_precision: 0.5723 - val_recall: 0.5323 - learning_rate: 1.0000e-04
# Epoch 13/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 258ms/step - accuracy: 0.5693 - auc: 0.6165 - loss: 0.6701 - precision: 0.5698 - recall: 0.5874 - val_accuracy: 0.5516 - val_auc: 0.6130 - val_loss: 0.6685 - val_precision: 0.5644 - val_recall: 0.4946 - learning_rate: 1.0000e-04
# Epoch 14/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 259ms/step - accuracy: 0.5763 - auc: 0.6190 - loss: 0.6697 - precision: 0.5762 - recall: 0.5943 - val_accuracy: 0.5543 - val_auc: 0.6182 - val_loss: 0.6679 - val_precision: 0.5733 - val_recall: 0.4624 - learning_rate: 1.0000e-04
# Epoch 15/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - accuracy: 0.5804 - auc: 0.6133 - loss: 0.6737 - precision: 0.5877 - recall: 0.5517 - val_accuracy: 0.5897 - val_auc: 0.6289 - val_loss: 0.6654 - val_precision: 0.6224 - val_recall: 0.4785 - learning_rate: 1.0000e-04
# Epoch 16/500
# 2025-06-11 23:09:12.351845: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 261ms/step - accuracy: 0.5843 - auc: 0.6138 - loss: 0.6754 - precision: 0.5916 - recall: 0.5597 - val_accuracy: 0.5897 - val_auc: 0.6324 - val_loss: 0.6647 - val_precision: 0.6471 - val_recall: 0.4140 - learning_rate: 1.0000e-04
# Epoch 17/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 262ms/step - accuracy: 0.5915 - auc: 0.6284 - loss: 0.6643 - precision: 0.6033 - recall: 0.5550 - val_accuracy: 0.5897 - val_auc: 0.6404 - val_loss: 0.6622 - val_precision: 0.6159 - val_recall: 0.5000 - learning_rate: 1.0000e-04
# Epoch 18/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 263ms/step - accuracy: 0.5793 - auc: 0.6105 - loss: 0.6726 - precision: 0.5876 - recall: 0.5482 - val_accuracy: 0.5842 - val_auc: 0.6330 - val_loss: 0.6620 - val_precision: 0.6107 - val_recall: 0.4892 - learning_rate: 1.0000e-04
# Epoch 19/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 264ms/step - accuracy: 0.6013 - auc: 0.6269 - loss: 0.6666 - precision: 0.6092 - recall: 0.5767 - val_accuracy: 0.5788 - val_auc: 0.6310 - val_loss: 0.6629 - val_precision: 0.6220 - val_recall: 0.4247 - learning_rate: 1.0000e-04
# Epoch 20/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5920 - auc: 0.6209 - loss: 0.6645 - precision: 0.6038 - recall: 0.5519 - val_accuracy: 0.5815 - val_auc: 0.6317 - val_loss: 0.6625 - val_precision: 0.6143 - val_recall: 0.4624 - learning_rate: 1.0000e-04
# Epoch 21/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 257ms/step - accuracy: 0.5862 - auc: 0.6219 - loss: 0.6676 - precision: 0.5880 - recall: 0.5889 - val_accuracy: 0.5951 - val_auc: 0.6374 - val_loss: 0.6589 - val_precision: 0.6178 - val_recall: 0.5215 - learning_rate: 1.0000e-04
# Epoch 22/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 258ms/step - accuracy: 0.5979 - auc: 0.6171 - loss: 0.6757 - precision: 0.6006 - recall: 0.5933 - val_accuracy: 0.5951 - val_auc: 0.6367 - val_loss: 0.6616 - val_precision: 0.6225 - val_recall: 0.5054 - learning_rate: 1.0000e-04
# Epoch 23/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 244ms/step - accuracy: 0.5911 - auc: 0.6351 - loss: 0.6666 - precision: 0.5985 - recall: 0.5675 - val_accuracy: 0.5897 - val_auc: 0.6380 - val_loss: 0.6625 - val_precision: 0.6101 - val_recall: 0.5215 - learning_rate: 1.0000e-04
# Epoch 24/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 247ms/step - accuracy: 0.5799 - auc: 0.6181 - loss: 0.6689 - precision: 0.5840 - recall: 0.5745 - val_accuracy: 0.5842 - val_auc: 0.6303 - val_loss: 0.6637 - val_precision: 0.5988 - val_recall: 0.5376 - learning_rate: 1.0000e-04
# Epoch 25/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 250ms/step - accuracy: 0.5945 - auc: 0.6360 - loss: 0.6598 - precision: 0.6035 - recall: 0.5680 - val_accuracy: 0.5707 - val_auc: 0.6292 - val_loss: 0.6628 - val_precision: 0.5909 - val_recall: 0.4892 - learning_rate: 1.0000e-04
# Epoch 26/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 268ms/step - accuracy: 0.6048 - auc: 0.6498 - loss: 0.6552 - precision: 0.6112 - recall: 0.5881 - val_accuracy: 0.5707 - val_auc: 0.6256 - val_loss: 0.6636 - val_precision: 0.5909 - val_recall: 0.4892 - learning_rate: 1.0000e-04
# Epoch 27/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 242ms/step - accuracy: 0.5789 - auc: 0.6218 - loss: 0.6681 - precision: 0.5860 - recall: 0.5527 - val_accuracy: 0.5842 - val_auc: 0.6339 - val_loss: 0.6607 - val_precision: 0.6078 - val_recall: 0.5000 - learning_rate: 1.0000e-04
# Epoch 28/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 260ms/step - accuracy: 0.5997 - auc: 0.6514 - loss: 0.6499 - precision: 0.6141 - recall: 0.5487 - val_accuracy: 0.6005 - val_auc: 0.6446 - val_loss: 0.6591 - val_precision: 0.6535 - val_recall: 0.4462 - learning_rate: 1.0000e-04
# Epoch 29/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 252ms/step - accuracy: 0.6004 - auc: 0.6402 - loss: 0.6586 - precision: 0.6067 - recall: 0.5882 - val_accuracy: 0.5815 - val_auc: 0.6372 - val_loss: 0.6602 - val_precision: 0.6081 - val_recall: 0.4839 - learning_rate: 1.0000e-04
# Epoch 30/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 241ms/step - accuracy: 0.6063 - auc: 0.6572 - loss: 0.6504 - precision: 0.6175 - recall: 0.5692 - val_accuracy: 0.5815 - val_auc: 0.6381 - val_loss: 0.6609 - val_precision: 0.5920 - val_recall: 0.5538 - learning_rate: 1.0000e-04
# Epoch 31/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 261ms/step - accuracy: 0.5742 - auc: 0.6212 - loss: 0.6658 - precision: 0.5828 - recall: 0.5417 - val_accuracy: 0.5978 - val_auc: 0.6441 - val_loss: 0.6579 - val_precision: 0.6234 - val_recall: 0.5161 - learning_rate: 1.0000e-04
# Epoch 32/500
# 2025-06-11 23:13:47.994498: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - accuracy: 0.6104 - auc: 0.6605 - loss: 0.6464 - precision: 0.6215 - recall: 0.5757 - val_accuracy: 0.5842 - val_auc: 0.6457 - val_loss: 0.6565 - val_precision: 0.6051 - val_recall: 0.5108 - learning_rate: 1.0000e-04
# Epoch 33/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 249ms/step - accuracy: 0.5937 - auc: 0.6364 - loss: 0.6540 - precision: 0.5994 - recall: 0.5783 - val_accuracy: 0.5978 - val_auc: 0.6416 - val_loss: 0.6593 - val_precision: 0.6092 - val_recall: 0.5699 - learning_rate: 1.0000e-04
# Epoch 34/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 236ms/step - accuracy: 0.6156 - auc: 0.6558 - loss: 0.6523 - precision: 0.6203 - recall: 0.6062 - val_accuracy: 0.6005 - val_auc: 0.6452 - val_loss: 0.6589 - val_precision: 0.6168 - val_recall: 0.5538 - learning_rate: 1.0000e-04
# Epoch 35/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 241ms/step - accuracy: 0.6111 - auc: 0.6542 - loss: 0.6530 - precision: 0.6199 - recall: 0.5861 - val_accuracy: 0.5870 - val_auc: 0.6419 - val_loss: 0.6575 - val_precision: 0.6076 - val_recall: 0.5161 - learning_rate: 1.0000e-04
# Epoch 36/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 239ms/step - accuracy: 0.5976 - auc: 0.6489 - loss: 0.6545 - precision: 0.6057 - recall: 0.5714 - val_accuracy: 0.5897 - val_auc: 0.6426 - val_loss: 0.6572 - val_precision: 0.6129 - val_recall: 0.5108 - learning_rate: 1.0000e-04
# Epoch 37/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.6194 - auc: 0.6768 - loss: 0.6377 - precision: 0.6239 - recall: 0.6114 - val_accuracy: 0.6005 - val_auc: 0.6510 - val_loss: 0.6519 - val_precision: 0.6242 - val_recall: 0.5269 - learning_rate: 1.0000e-04
# Epoch 38/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 252ms/step - accuracy: 0.6187 - auc: 0.6765 - loss: 0.6404 - precision: 0.6363 - recall: 0.5638 - val_accuracy: 0.6141 - val_auc: 0.6608 - val_loss: 0.6482 - val_precision: 0.6528 - val_recall: 0.5054 - learning_rate: 1.0000e-04
# Epoch 39/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 240ms/step - accuracy: 0.6076 - auc: 0.6517 - loss: 0.6564 - precision: 0.6214 - recall: 0.5629 - val_accuracy: 0.6168 - val_auc: 0.6549 - val_loss: 0.6497 - val_precision: 0.6331 - val_recall: 0.5753 - learning_rate: 1.0000e-04
# Epoch 40/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 245ms/step - accuracy: 0.6140 - auc: 0.6596 - loss: 0.6506 - precision: 0.6238 - recall: 0.5814 - val_accuracy: 0.6087 - val_auc: 0.6650 - val_loss: 0.6494 - val_precision: 0.6382 - val_recall: 0.5215 - learning_rate: 1.0000e-04
# Epoch 41/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5951 - auc: 0.6480 - loss: 0.6537 - precision: 0.6051 - recall: 0.5625 - val_accuracy: 0.6114 - val_auc: 0.6567 - val_loss: 0.6524 - val_precision: 0.6405 - val_recall: 0.5269 - learning_rate: 1.0000e-04
# Epoch 42/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 242ms/step - accuracy: 0.6107 - auc: 0.6471 - loss: 0.6539 - precision: 0.6231 - recall: 0.5756 - val_accuracy: 0.6277 - val_auc: 0.6618 - val_loss: 0.6513 - val_precision: 0.6644 - val_recall: 0.5323 - learning_rate: 1.0000e-04
# Epoch 43/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 263ms/step - accuracy: 0.6162 - auc: 0.6548 - loss: 0.6524 - precision: 0.6280 - recall: 0.5820 - val_accuracy: 0.6250 - val_auc: 0.6656 - val_loss: 0.6495 - val_precision: 0.6600 - val_recall: 0.5323 - learning_rate: 1.0000e-04
# Epoch 44/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 243ms/step - accuracy: 0.6093 - auc: 0.6660 - loss: 0.6445 - precision: 0.6148 - recall: 0.5977 - val_accuracy: 0.6196 - val_auc: 0.6625 - val_loss: 0.6510 - val_precision: 0.6797 - val_recall: 0.4677 - learning_rate: 1.0000e-04
# Epoch 45/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 244ms/step - accuracy: 0.6077 - auc: 0.6681 - loss: 0.6428 - precision: 0.6236 - recall: 0.5544 - val_accuracy: 0.6168 - val_auc: 0.6580 - val_loss: 0.6509 - val_precision: 0.6510 - val_recall: 0.5215 - learning_rate: 1.0000e-04
# Epoch 46/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - accuracy: 0.6213 - auc: 0.6638 - loss: 0.6482 - precision: 0.6395 - recall: 0.5687 - val_accuracy: 0.6250 - val_auc: 0.6599 - val_loss: 0.6495 - val_precision: 0.6714 - val_recall: 0.5054 - learning_rate: 1.0000e-04
# Epoch 47/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.6283 - auc: 0.6756 - loss: 0.6418 - precision: 0.6426 - recall: 0.5884 - val_accuracy: 0.6250 - val_auc: 0.6676 - val_loss: 0.6465 - val_precision: 0.6791 - val_recall: 0.4892 - learning_rate: 1.0000e-04
# Epoch 48/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.6265 - auc: 0.6724 - loss: 0.6414 - precision: 0.6354 - recall: 0.6036 - val_accuracy: 0.6114 - val_auc: 0.6685 - val_loss: 0.6469 - val_precision: 0.6777 - val_recall: 0.4409 - learning_rate: 1.0000e-04
# Epoch 49/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - accuracy: 0.6030 - auc: 0.6507 - loss: 0.6529 - precision: 0.6163 - recall: 0.5580 - val_accuracy: 0.6005 - val_auc: 0.6647 - val_loss: 0.6490 - val_precision: 0.6585 - val_recall: 0.4355 - learning_rate: 1.0000e-04
# Epoch 50/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.6197 - auc: 0.6707 - loss: 0.6419 - precision: 0.6388 - recall: 0.5668 - val_accuracy: 0.6060 - val_auc: 0.6702 - val_loss: 0.6468 - val_precision: 0.6454 - val_recall: 0.4892 - learning_rate: 1.0000e-04
# Epoch 51/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.6228 - auc: 0.6765 - loss: 0.6401 - precision: 0.6321 - recall: 0.5955 - val_accuracy: 0.6332 - val_auc: 0.6715 - val_loss: 0.6469 - val_precision: 0.6917 - val_recall: 0.4946 - learning_rate: 1.0000e-04
# Epoch 52/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - accuracy: 0.5899 - auc: 0.6481 - loss: 0.6531 - precision: 0.6067 - recall: 0.5247 - val_accuracy: 0.6087 - val_auc: 0.6668 - val_loss: 0.6473 - val_precision: 0.6544 - val_recall: 0.4785 - learning_rate: 1.0000e-04
# Epoch 53/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 255ms/step - accuracy: 0.6169 - auc: 0.6636 - loss: 0.6437 - precision: 0.6277 - recall: 0.5849 - val_accuracy: 0.6005 - val_auc: 0.6681 - val_loss: 0.6475 - val_precision: 0.6489 - val_recall: 0.4570 - learning_rate: 1.0000e-04
# Epoch 54/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 240ms/step - accuracy: 0.6122 - auc: 0.6719 - loss: 0.6389 - precision: 0.6233 - recall: 0.5787 - val_accuracy: 0.6168 - val_auc: 0.6648 - val_loss: 0.6465 - val_precision: 0.6692 - val_recall: 0.4785 - learning_rate: 1.0000e-04
# Epoch 55/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.6219 - auc: 0.6653 - loss: 0.6435 - precision: 0.6485 - recall: 0.5420 - val_accuracy: 0.6033 - val_auc: 0.6591 - val_loss: 0.6474 - val_precision: 0.6389 - val_recall: 0.4946 - learning_rate: 1.0000e-04
# Epoch 56/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 250ms/step - accuracy: 0.6328 - auc: 0.6887 - loss: 0.6315 - precision: 0.6451 - recall: 0.5999 - val_accuracy: 0.6087 - val_auc: 0.6549 - val_loss: 0.6484 - val_precision: 0.6591 - val_recall: 0.4677 - learning_rate: 1.0000e-04
# Epoch 57/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 238ms/step - accuracy: 0.6307 - auc: 0.6742 - loss: 0.6449 - precision: 0.6515 - recall: 0.5726 - val_accuracy: 0.5978 - val_auc: 0.6580 - val_loss: 0.6487 - val_precision: 0.6319 - val_recall: 0.4892 - learning_rate: 1.0000e-04
# Epoch 58/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 247ms/step - accuracy: 0.6037 - auc: 0.6557 - loss: 0.6495 - precision: 0.6146 - recall: 0.5688 - val_accuracy: 0.6005 - val_auc: 0.6565 - val_loss: 0.6488 - val_precision: 0.6364 - val_recall: 0.4892 - learning_rate: 2.0000e-05
# Epoch 59/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 259ms/step - accuracy: 0.6278 - auc: 0.6907 - loss: 0.6270 - precision: 0.6463 - recall: 0.5761 - val_accuracy: 0.5978 - val_auc: 0.6566 - val_loss: 0.6484 - val_precision: 0.6284 - val_recall: 0.5000 - learning_rate: 2.0000e-05
# Epoch 60/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.6291 - auc: 0.6686 - loss: 0.6436 - precision: 0.6467 - recall: 0.5818 - val_accuracy: 0.5951 - val_auc: 0.6592 - val_loss: 0.6479 - val_precision: 0.6225 - val_recall: 0.5054 - learning_rate: 2.0000e-05
# Epoch 61/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 261ms/step - accuracy: 0.6012 - auc: 0.6569 - loss: 0.6465 - precision: 0.6134 - recall: 0.5631 - val_accuracy: 0.6005 - val_auc: 0.6606 - val_loss: 0.6475 - val_precision: 0.6309 - val_recall: 0.5054 - learning_rate: 2.0000e-05
# Epoch 62/500
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.6206 - auc: 0.6821 - loss: 0.6357 - precision: 0.6338 - recall: 0.5847
# 2025-06-11 23:22:22.909230: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 2025-06-11 23:22:22.909430: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 424759287793874885
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 20s 290ms/step - accuracy: 0.6207 - auc: 0.6820 - loss: 0.6356 - precision: 0.6338 - recall: 0.5853 - val_accuracy: 0.6005 - val_auc: 0.6615 - val_loss: 0.6469 - val_precision: 0.6403 - val_recall: 0.4785 - learning_rate: 2.0000e-05
# Epoch 63/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 19s 279ms/step - accuracy: 0.5891 - auc: 0.6558 - loss: 0.6471 - precision: 0.6046 - recall: 0.5289 - val_accuracy: 0.6060 - val_auc: 0.6660 - val_loss: 0.6466 - val_precision: 0.6414 - val_recall: 0.5000 - learning_rate: 2.0000e-05
# Epoch 64/500
# 2025-06-11 23:22:45.253817: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 262ms/step - accuracy: 0.6363 - auc: 0.6922 - loss: 0.6311 - precision: 0.6543 - recall: 0.5865 - val_accuracy: 0.6033 - val_auc: 0.6644 - val_loss: 0.6462 - val_precision: 0.6408 - val_recall: 0.4892 - learning_rate: 2.0000e-05
# Epoch 65/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 258ms/step - accuracy: 0.6229 - auc: 0.6799 - loss: 0.6391 - precision: 0.6401 - recall: 0.5735 - val_accuracy: 0.6005 - val_auc: 0.6655 - val_loss: 0.6462 - val_precision: 0.6327 - val_recall: 0.5000 - learning_rate: 2.0000e-05
# Epoch 66/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 264ms/step - accuracy: 0.6191 - auc: 0.6731 - loss: 0.6387 - precision: 0.6386 - recall: 0.5586 - val_accuracy: 0.6033 - val_auc: 0.6646 - val_loss: 0.6464 - val_precision: 0.6389 - val_recall: 0.4946 - learning_rate: 2.0000e-05
# Epoch 67/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 257ms/step - accuracy: 0.6216 - auc: 0.6731 - loss: 0.6384 - precision: 0.6344 - recall: 0.5807 - val_accuracy: 0.6060 - val_auc: 0.6621 - val_loss: 0.6465 - val_precision: 0.6395 - val_recall: 0.5054 - learning_rate: 2.0000e-05
# Epoch 68/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 267ms/step - accuracy: 0.6103 - auc: 0.6703 - loss: 0.6421 - precision: 0.6218 - recall: 0.5717 - val_accuracy: 0.6005 - val_auc: 0.6612 - val_loss: 0.6467 - val_precision: 0.6364 - val_recall: 0.4892 - learning_rate: 2.0000e-05
# Epoch 69/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 256ms/step - accuracy: 0.6322 - auc: 0.6740 - loss: 0.6386 - precision: 0.6522 - recall: 0.5763 - val_accuracy: 0.6005 - val_auc: 0.6629 - val_loss: 0.6469 - val_precision: 0.6403 - val_recall: 0.4785 - learning_rate: 2.0000e-05
# Epoch 70/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 268ms/step - accuracy: 0.6262 - auc: 0.6858 - loss: 0.6340 - precision: 0.6367 - recall: 0.5981 - val_accuracy: 0.6060 - val_auc: 0.6634 - val_loss: 0.6469 - val_precision: 0.6414 - val_recall: 0.5000 - learning_rate: 2.0000e-05
# Epoch 71/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 263ms/step - accuracy: 0.6180 - auc: 0.6781 - loss: 0.6361 - precision: 0.6353 - recall: 0.5666 - val_accuracy: 0.5924 - val_auc: 0.6606 - val_loss: 0.6474 - val_precision: 0.6304 - val_recall: 0.4677 - learning_rate: 2.0000e-05
# Epoch 72/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 258ms/step - accuracy: 0.6167 - auc: 0.6746 - loss: 0.6354 - precision: 0.6329 - recall: 0.5667 - val_accuracy: 0.5951 - val_auc: 0.6616 - val_loss: 0.6469 - val_precision: 0.6331 - val_recall: 0.4731 - learning_rate: 2.0000e-05
# Epoch 73/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 244ms/step - accuracy: 0.6334 - auc: 0.6899 - loss: 0.6307 - precision: 0.6507 - recall: 0.5854 - val_accuracy: 0.5951 - val_auc: 0.6636 - val_loss: 0.6462 - val_precision: 0.6312 - val_recall: 0.4785 - learning_rate: 2.0000e-05
# Epoch 74/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.6161 - auc: 0.6777 - loss: 0.6350 - precision: 0.6284 - recall: 0.5786 - val_accuracy: 0.6060 - val_auc: 0.6653 - val_loss: 0.6454 - val_precision: 0.6395 - val_recall: 0.5054 - learning_rate: 2.0000e-05
# Epoch 75/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 261ms/step - accuracy: 0.6551 - auc: 0.6994 - loss: 0.6294 - precision: 0.6660 - recall: 0.6275 - val_accuracy: 0.6087 - val_auc: 0.6686 - val_loss: 0.6441 - val_precision: 0.6400 - val_recall: 0.5161 - learning_rate: 2.0000e-05
# Epoch 76/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 244ms/step - accuracy: 0.6239 - auc: 0.6701 - loss: 0.6423 - precision: 0.6332 - recall: 0.5973 - val_accuracy: 0.6087 - val_auc: 0.6673 - val_loss: 0.6449 - val_precision: 0.6438 - val_recall: 0.5054 - learning_rate: 2.0000e-05
# Loading best weights from head training...
#
# Phase 4b: Fine-tuning (Unfreezing some base model layers)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ avg_pool                        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ top_dropout_1 (Dropout)         │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_128 (Dense)               │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ top_dropout_2 (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ top_dropout_3 (Dropout)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,858,305 (91.01 MB)
#  Trainable params: 270,593 (1.03 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Epoch 77/600
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 32s 348ms/step - accuracy: 0.5999 - auc: 0.6504 - loss: 0.6551 - precision: 0.6211 - recall: 0.5417 - val_accuracy: 0.6223 - val_auc: 0.6703 - val_loss: 0.6475 - val_precision: 0.6715 - val_recall: 0.4946 - learning_rate: 1.0000e-05
# Epoch 78/600
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 243ms/step - accuracy: 0.6146 - auc: 0.6718 - loss: 0.6412 - precision: 0.6208 - recall: 0.6013 - val_accuracy: 0.6168 - val_auc: 0.6682 - val_loss: 0.6473 - val_precision: 0.6596 - val_recall: 0.5000 - learning_rate: 1.0000e-05
# Epoch 79/600
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 260ms/step - accuracy: 0.6388 - auc: 0.6787 - loss: 0.6392 - precision: 0.6505 - recall: 0.6068 - val_accuracy: 0.6141 - val_auc: 0.6673 - val_loss: 0.6476 - val_precision: 0.6549 - val_recall: 0.5000 - learning_rate: 1.0000e-05
# Epoch 80/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6279 - auc: 0.6724 - loss: 0.6432 - precision: 0.6434 - recall: 0.5849
# 2025-06-11 23:27:53.777285: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 241ms/step - accuracy: 0.6276 - auc: 0.6721 - loss: 0.6434 - precision: 0.6431 - recall: 0.5847 - val_accuracy: 0.6168 - val_auc: 0.6669 - val_loss: 0.6475 - val_precision: 0.6596 - val_recall: 0.5000 - learning_rate: 1.0000e-05
# Epoch 81/600
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 249ms/step - accuracy: 0.6282 - auc: 0.6882 - loss: 0.6330 - precision: 0.6333 - recall: 0.6192 - val_accuracy: 0.6087 - val_auc: 0.6669 - val_loss: 0.6475 - val_precision: 0.6522 - val_recall: 0.4839 - learning_rate: 1.0000e-05
# Epoch 82/600
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 240ms/step - accuracy: 0.6113 - auc: 0.6651 - loss: 0.6492 - precision: 0.6293 - recall: 0.5532 - val_accuracy: 0.6087 - val_auc: 0.6668 - val_loss: 0.6474 - val_precision: 0.6522 - val_recall: 0.4839 - learning_rate: 1.0000e-05
# Epoch 83/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.5988 - auc: 0.6565 - loss: 0.6434 - precision: 0.6042 - recall: 0.5879
# 2025-06-11 23:28:42.795894: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - accuracy: 0.5988 - auc: 0.6564 - loss: 0.6434 - precision: 0.6043 - recall: 0.5878 - val_accuracy: 0.6087 - val_auc: 0.6653 - val_loss: 0.6475 - val_precision: 0.6522 - val_recall: 0.4839 - learning_rate: 1.0000e-05
# Epoch 84/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.5941 - auc: 0.6522 - loss: 0.6540 - precision: 0.5995 - recall: 0.5814
# 2025-06-11 23:28:59.606572: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5944 - auc: 0.6526 - loss: 0.6537 - precision: 0.5999 - recall: 0.5816 - val_accuracy: 0.6196 - val_auc: 0.6651 - val_loss: 0.6474 - val_precision: 0.6643 - val_recall: 0.5000 - learning_rate: 1.0000e-05
# Epoch 85/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.6192 - auc: 0.6678 - loss: 0.6474 - precision: 0.6320 - recall: 0.5803
# 2025-06-11 23:29:17.833622: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 270ms/step - accuracy: 0.6188 - auc: 0.6674 - loss: 0.6476 - precision: 0.6316 - recall: 0.5802 - val_accuracy: 0.6141 - val_auc: 0.6661 - val_loss: 0.6473 - val_precision: 0.6571 - val_recall: 0.4946 - learning_rate: 1.0000e-05
# Epoch 86/600
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 234ms/step - accuracy: 0.6268 - auc: 0.6667 - loss: 0.6492 - precision: 0.6341 - recall: 0.6097 - val_accuracy: 0.6114 - val_auc: 0.6673 - val_loss: 0.6477 - val_precision: 0.6525 - val_recall: 0.4946 - learning_rate: 1.0000e-05
# Epoch 87/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.6381 - auc: 0.6996 - loss: 0.6295 - precision: 0.6509 - recall: 0.6029
# 2025-06-11 23:29:50.768013: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 248ms/step - accuracy: 0.6376 - auc: 0.6987 - loss: 0.6299 - precision: 0.6504 - recall: 0.6023 - val_accuracy: 0.6114 - val_auc: 0.6664 - val_loss: 0.6478 - val_precision: 0.6569 - val_recall: 0.4839 - learning_rate: 1.0000e-05
# Epoch 88/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6577 - auc: 0.7011 - loss: 0.6274 - precision: 0.6702 - recall: 0.6301
# 2025-06-11 23:30:06.750730: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 236ms/step - accuracy: 0.6574 - auc: 0.7005 - loss: 0.6278 - precision: 0.6700 - recall: 0.6298 - val_accuracy: 0.6060 - val_auc: 0.6646 - val_loss: 0.6479 - val_precision: 0.6475 - val_recall: 0.4839 - learning_rate: 1.0000e-05
# Epoch 89/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.6250 - auc: 0.6771 - loss: 0.6381 - precision: 0.6347 - recall: 0.5980
# 2025-06-11 23:30:22.860965: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 2025-06-11 23:30:22.860980: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 424759287793874885
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 238ms/step - accuracy: 0.6249 - auc: 0.6769 - loss: 0.6381 - precision: 0.6346 - recall: 0.5979 - val_accuracy: 0.6114 - val_auc: 0.6651 - val_loss: 0.6478 - val_precision: 0.6525 - val_recall: 0.4946 - learning_rate: 2.0000e-06
# Epoch 90/600
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 242ms/step - accuracy: 0.5935 - auc: 0.6439 - loss: 0.6537 - precision: 0.6015 - recall: 0.5663 - val_accuracy: 0.6114 - val_auc: 0.6642 - val_loss: 0.6479 - val_precision: 0.6525 - val_recall: 0.4946 - learning_rate: 2.0000e-06
# Epoch 91/600
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 227ms/step - accuracy: 0.6157 - auc: 0.6715 - loss: 0.6402 - precision: 0.6278 - recall: 0.5808 - val_accuracy: 0.6114 - val_auc: 0.6645 - val_loss: 0.6478 - val_precision: 0.6525 - val_recall: 0.4946 - learning_rate: 2.0000e-06
# Epoch 92/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.6045 - auc: 0.6545 - loss: 0.6476 - precision: 0.6164 - recall: 0.5661
# 2025-06-11 23:31:11.407730: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6045 - auc: 0.6543 - loss: 0.6476 - precision: 0.6164 - recall: 0.5666 - val_accuracy: 0.6087 - val_auc: 0.6645 - val_loss: 0.6478 - val_precision: 0.6500 - val_recall: 0.4892 - learning_rate: 2.0000e-06
# Epoch 93/600
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 242ms/step - accuracy: 0.6114 - auc: 0.6731 - loss: 0.6389 - precision: 0.6250 - recall: 0.5699 - val_accuracy: 0.6033 - val_auc: 0.6648 - val_loss: 0.6479 - val_precision: 0.6449 - val_recall: 0.4785 - learning_rate: 2.0000e-06
# Epoch 94/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.6248 - auc: 0.6789 - loss: 0.6415 - precision: 0.6330 - recall: 0.6040
# 2025-06-11 23:31:44.809601: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.6250 - auc: 0.6788 - loss: 0.6415 - precision: 0.6333 - recall: 0.6041 - val_accuracy: 0.6033 - val_auc: 0.6647 - val_loss: 0.6479 - val_precision: 0.6449 - val_recall: 0.4785 - learning_rate: 2.0000e-06
# Epoch 95/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.6079 - auc: 0.6594 - loss: 0.6489 - precision: 0.6173 - recall: 0.5783
# 2025-06-11 23:32:01.170288: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 246ms/step - accuracy: 0.6081 - auc: 0.6593 - loss: 0.6490 - precision: 0.6177 - recall: 0.5785 - val_accuracy: 0.6033 - val_auc: 0.6648 - val_loss: 0.6478 - val_precision: 0.6449 - val_recall: 0.4785 - learning_rate: 2.0000e-06
# Epoch 96/600
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.6233 - auc: 0.6774 - loss: 0.6349 - precision: 0.6382 - recall: 0.5789
# 2025-06-11 23:32:18.466196: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 10284803553739154503
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.6233 - auc: 0.6773 - loss: 0.6349 - precision: 0.6383 - recall: 0.5790 - val_accuracy: 0.6087 - val_auc: 0.6653 - val_loss: 0.6478 - val_precision: 0.6544 - val_recall: 0.4785 - learning_rate: 2.0000e-06
# Epoch 97/600
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.6279 - auc: 0.6812 - loss: 0.6381 - precision: 0.6369 - recall: 0.6011 - val_accuracy: 0.6033 - val_auc: 0.6646 - val_loss: 0.6479 - val_precision: 0.6449 - val_recall: 0.4785 - learning_rate: 2.0000e-06
# Loading best weights from fine-tuning...
#
# Phase 5: Evaluating the Model on Test Set
#      13/Unknown 3s 216ms/step - accuracy: 0.6339 - auc: 0.6716 - loss: 0.6462 - precision: 0.6388 - recall: 0.5435
# 2025-06-11 23:32:44.782391: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.162 = (f32[17,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,64,56,56]{3,2,1,0} %bitcast.5280, f32[64,64,3,3]{3,2,1,0} %bitcast.5287, f32[64]{0} %bitcast.5289), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv2_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:32:45.623578: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.172 = (f32[17,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,128,28,28]{3,2,1,0} %bitcast.5685, f32[128,128,3,3]{3,2,1,0} %bitcast.5692, f32[128]{0} %bitcast.5694), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv3_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:32:46.413059: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.185 = (f32[17,256,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,256,14,14]{3,2,1,0} %bitcast.6213, f32[256,256,3,3]{3,2,1,0} %bitcast.6220, f32[256]{0} %bitcast.6222), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv4_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-11 23:32:47.165404: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.204 = (f32[17,512,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,512,7,7]{3,2,1,0} %bitcast.6987, f32[512,512,3,3]{3,2,1,0} %bitcast.6994, f32[512]{0} %bitcast.6996), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/resnet50_1/conv5_block1_2_conv_1/convolution" source_file="/home/luui/.pyenv/versions/3.10.16/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 583ms/step - accuracy: 0.6322 - auc: 0.6728 - loss: 0.6452 - precision: 0.6425 - recall: 0.5371
# Final Loss: 0.6386656165122986
# Final Accuracy: 0.6212471127510071
# Final AUC: 0.6803499460220337
# Final Precision: 0.6666666865348816
# Final Recall: 0.4954128563404083
# Number of results: 5
# Results: [0.6386656165122986, 0.6212471127510071, 0.6803499460220337, 0.6666666865348816, 0.4954128563404083]
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 351ms/step
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#       BENIGN       0.59      0.75      0.66       215
#    MALIGNANT       0.67      0.50      0.57       218
#
#     accuracy                           0.62       433
#    macro avg       0.63      0.62      0.62       433
# weighted avg       0.63      0.62      0.62       433
#
#
# Confusion Matrix (Test Set):
# [[161  54]
#  [110 108]]
# Confusion matrix saved to ./run_ResNet50_20250611_230341/confusion_matrix.png
# Available metrics names: ['loss', 'compile_metrics']
# Training history plot saved to ./run_ResNet50_20250611_230341/training_history_Acc0.621_AUC0.680.png
# --- End of Training ---
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
